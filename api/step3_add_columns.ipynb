# %%
import pandas as pd
import numpy as np
import requests
from pprint import PrettyPrinter

# %%
df = pd.read_csv ('Dropped_Less_than_1000_budget_and_other_columns.csv')
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df['number_of_genres'] = df.genre.str.split(',', expand=False).agg([len])
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df['number_of_languages'] = df.language.str.split(',', expand=False).agg([len])
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df['first_genre'] = df['genre'].str.split(' ').str[0]
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df = df.drop(columns=['make'])
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df['first_genre']=df['first_genre'].replace( '[\,)]','', regex=True )
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df.to_csv('Added_FirstGenre_column.csv', encoding='utf-8', index=False)

# %%
df['Good_or_Bad_Movie_6_or_higher'] = np.where(df['avg_vote']>= 6, 1, 0)

# %%
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df.to_csv('Added_good_or_bad_6_column.csv', encoding='utf-8', index=False)

# %%
df['Good_or_Bad_Movie_8_or_higher'] = np.where(df['avg_vote']>= 8, 1, 0)

# %%
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df.to_csv('Added_good_or_bad_8_column.csv', encoding='utf-8', index=False)
