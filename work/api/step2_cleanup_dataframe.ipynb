# %%
import pandas as pd
import numpy as np
import requests
from pprint import PrettyPrinter

# %%
df = pd.read_csv ('Movies_with_Good_and_bad_column.csv')
df
# Out:
#       imdb_title_id                               title  \
# 0         tt7939428  10 cose da fare prima di lasciarsi
# 1        tt10740584                    Abigail Haunting
# 2        tt11032990      Malibu Rescue - Una nuova onda
# 3         tt8461224                   The Tax Collector
# 4        tt11316764                       Rocket Hunter
# ...             ...                                 ...
# 10386     tt0004465               The Perils of Pauline
# 10387     tt0004181                  Judith of Bethulia
# 10388     tt0004099    His Majesty, the Scarecrow of Oz
# 10389     tt0003471                    Traffic in Souls
# 10390     tt0002101                           Cleopatra
#
#                                   original_title  year date_published  \
# 0      10 Things We Should Do Before We Break Up  2020      2/21/2020
# 1                               Abigail Haunting  2020      3/27/2020
# 2                   Malibu Rescue: The Next Wave  2020       8/4/2020
# ...

# %%
df = df.drop(columns=['title', 'date_published', 'country', 'director', 'writer', 'actors', 'description', 'usa_gross_income', 'worlwide_gross_income', 'metascore', 'reviews_from_users', 'reviews_from_critics'  ])
print(df.head())
# Out:
#   imdb_title_id                             original_title  year  \
# 0     tt7939428  10 Things We Should Do Before We Break Up  2020
# 1    tt10740584                           Abigail Haunting  2020
# 2    tt11032990               Malibu Rescue: The Next Wave  2020
# 3     tt8461224                          The Tax Collector  2020
# 4    tt11316764                              Rocket Hunter  2020
#
#                        genre  duration language         production_company  \
# 0                    Romance        74  English                        NaN
# 1                     Horror        85  English         Indie Film Factory
# 2  Action, Adventure, Comedy        68  English  Pacific Bay Entertainment
# 3       Action, Crime, Drama        95  English   Cedar Park Entertainment
# 4         Action, Drama, War        86  English                        NaN
#
#    avg_vote  votes        budget  Good_or_Bad_Movie
# 0       4.7    486  $25,000,000                   0
# ...

# %%
df.head()
# Out:
#   imdb_title_id                             original_title  year  \
# 0     tt7939428  10 Things We Should Do Before We Break Up  2020
# 1    tt10740584                           Abigail Haunting  2020
# 2    tt11032990               Malibu Rescue: The Next Wave  2020
# 3     tt8461224                          The Tax Collector  2020
# 4    tt11316764                              Rocket Hunter  2020
#
#                        genre  duration language         production_company  \
# 0                    Romance        74  English                        NaN
# 1                     Horror        85  English         Indie Film Factory
# 2  Action, Adventure, Comedy        68  English  Pacific Bay Entertainment
# 3       Action, Crime, Drama        95  English   Cedar Park Entertainment
# 4         Action, Drama, War        86  English                        NaN
#
#    avg_vote  votes        budget  Good_or_Bad_Movie
# 0       4.7    486  $25,000,000                   0
# ...

# %%
print(df.dtypes)
# Out:
# imdb_title_id          object
# original_title         object
# year                    int64
# genre                  object
# duration                int64
# language               object
# production_company     object
# avg_vote              float64
# votes                   int64
# budget                 object
# Good_or_Bad_Movie       int64
# dtype: object

# %%
df['budget']=df['budget'].replace( '[\$,)]','', regex=True ).astype(int)

# %%
print(df.dtypes)
# Out:
# imdb_title_id          object
# original_title         object
# year                    int64
# genre                  object
# duration                int64
# language               object
# production_company     object
# avg_vote              float64
# votes                   int64
# budget                  int32
# Good_or_Bad_Movie       int64
# dtype: object

# %%
df.head()
# Out:
#   imdb_title_id                             original_title  year  \
# 0     tt7939428  10 Things We Should Do Before We Break Up  2020
# 1    tt10740584                           Abigail Haunting  2020
# 2    tt11032990               Malibu Rescue: The Next Wave  2020
# 3     tt8461224                          The Tax Collector  2020
# 4    tt11316764                              Rocket Hunter  2020
#
#                        genre  duration language         production_company  \
# 0                    Romance        74  English                        NaN
# 1                     Horror        85  English         Indie Film Factory
# 2  Action, Adventure, Comedy        68  English  Pacific Bay Entertainment
# 3       Action, Crime, Drama        95  English   Cedar Park Entertainment
# 4         Action, Drama, War        86  English                        NaN
#
#    avg_vote  votes    budget  Good_or_Bad_Movie
# 0       4.7    486  25000000                  0
# ...

# %%
index_names = df[ df['budget'] < 1000 ].index 
df.drop(index_names, inplace = True) 
df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 5        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10386     tt0004465                      The Perils of Pauline  1914
# 10387     tt0004181                         Judith of Bethulia  1914
# 10388     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10389     tt0003471                           Traffic in Souls  1913
# 10390     tt0002101                                  Cleopatra  1912
#
#                             genre  duration language  \
# 0                         Romance        74  English
# ...

# %%
df.to_csv('Dropped_Less_than_1000_budget_and_other_columns.csv', encoding='utf-8', index=False)
