# %%
#import dependencies and set-up
import pandas as pd
import matplotlib.pyplot as plt
import csv
import os
from scipy.stats import linregress
import scipy.stats as st
import matplotlib as mpl
import matplotlib.ticker as ticker
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data_path = "Resources/movie2.csv"

movie_df = pd.read_csv(data_path)
movie_df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                            genre2  duration language  \
# 0                         Romance        74  English
# 1                          Horror        85  English
# 2       Action, Adventure, Comedy        68  English
# 3            Action, Crime, Drama        95  English
# 4                          Horror        82  English
# ...                           ...       ...      ...
# 10340    Action, Adventure, Drama       199  English
# 10341                       Drama        61  English
# 10342  Family, Fantasy, Adventure        59  English
# 10343                Crime, Drama        88  English
# 10344              Drama, History       100  English
#
#                                      production_company  avg_vote  votes  \
# 0                                                   NaN       4.7    486
# 1                                    Indie Film Factory       3.8    398
# 2                             Pacific Bay Entertainment       4.5    386
# 3                              Cedar Park Entertainment       4.7   4862
# 4                                Sterling Entertainment       2.2    114
# ...                                                 ...       ...    ...
# 10340                                    Path̩ Fr̬res       6.3    939
# 10341                                  Biograph Company       6.1   1239
# 10342                 The Oz Film Manufacturing Company       5.2    415
# 10343  Independent Moving Pictures Co. of America (IMP)       6.0    552
# 10344                     Helen Gardner Picture Players       5.2    446
#
#          budget  Good_or_Bad_Movie  number_of_genres  number_of_languages  \
# 0      25000000                  0                 1                    1
# 1         60000                  0                 1                    1
# 2       5000000                  0                 3                    1
# 3      30000000                  0                 3                    1
# 4         10000                  0                 1                    1
# ...         ...                ...               ...                  ...
# 10340     25000                  0                 3                    1
# 10341     40000                  0                 1                    1
# 10342     23500                  0                 3                    1
# 10343      5700                  0                 2                    1
# 10344     45000                  0                 2                    1
#
#          genre  Good_or_Bad_Movie_6_or_higher  Good_or_Bad_Movie_8_or_higher
# 0      Romance                              0                              0
# 1       Horror                              0                              0
# 2       Action                              0                              0
# 3       Action                              0                              0
# 4       Horror                              0                              0
# ...        ...                            ...                            ...
# 10340   Action                              1                              0
# 10341    Drama                              1                              0
# 10342   Family                              0                              0
# 10343    Crime                              1                              0
# 10344    Drama                              0                              0
#
# [10345 rows x 16 columns]

# %%
movie_df["genre"]= movie_df["genre"].str.split(',', expand=True)
movie_df
# Out:
#       imdb_title_id                             original_title  year  \
# 0         tt7939428  10 Things We Should Do Before We Break Up  2020
# 1        tt10740584                           Abigail Haunting  2020
# 2        tt11032990               Malibu Rescue: The Next Wave  2020
# 3         tt8461224                          The Tax Collector  2020
# 4        tt11547496                  Camp Blood 8: Revelations  2020
# ...             ...                                        ...   ...
# 10340     tt0004465                      The Perils of Pauline  1914
# 10341     tt0004181                         Judith of Bethulia  1914
# 10342     tt0004099           His Majesty, the Scarecrow of Oz  1914
# 10343     tt0003471                           Traffic in Souls  1913
# 10344     tt0002101                                  Cleopatra  1912
#
#                            genre2  duration language  \
# 0                         Romance        74  English
# 1                          Horror        85  English
# 2       Action, Adventure, Comedy        68  English
# 3            Action, Crime, Drama        95  English
# 4                          Horror        82  English
# ...                           ...       ...      ...
# 10340    Action, Adventure, Drama       199  English
# 10341                       Drama        61  English
# 10342  Family, Fantasy, Adventure        59  English
# 10343                Crime, Drama        88  English
# 10344              Drama, History       100  English
#
#                                      production_company  avg_vote  votes  \
# 0                                                   NaN       4.7    486
# 1                                    Indie Film Factory       3.8    398
# 2                             Pacific Bay Entertainment       4.5    386
# 3                              Cedar Park Entertainment       4.7   4862
# 4                                Sterling Entertainment       2.2    114
# ...                                                 ...       ...    ...
# 10340                                    Path̩ Fr̬res       6.3    939
# 10341                                  Biograph Company       6.1   1239
# 10342                 The Oz Film Manufacturing Company       5.2    415
# 10343  Independent Moving Pictures Co. of America (IMP)       6.0    552
# 10344                     Helen Gardner Picture Players       5.2    446
#
#          budget  Good_or_Bad_Movie  number_of_genres  number_of_languages  \
# 0      25000000                  0                 1                    1
# 1         60000                  0                 1                    1
# 2       5000000                  0                 3                    1
# 3      30000000                  0                 3                    1
# 4         10000                  0                 1                    1
# ...         ...                ...               ...                  ...
# 10340     25000                  0                 3                    1
# 10341     40000                  0                 1                    1
# 10342     23500                  0                 3                    1
# 10343      5700                  0                 2                    1
# 10344     45000                  0                 2                    1
#
#          genre  Good_or_Bad_Movie_6_or_higher  Good_or_Bad_Movie_8_or_higher
# 0      Romance                              0                              0
# 1       Horror                              0                              0
# 2       Action                              0                              0
# 3       Action                              0                              0
# 4       Horror                              0                              0
# ...        ...                            ...                            ...
# 10340   Action                              1                              0
# 10341    Drama                              1                              0
# 10342   Family                              0                              0
# 10343    Crime                              1                              0
# 10344    Drama                              0                              0
#
# [10345 rows x 16 columns]

# %%
year_gb = movie_df.groupby(["year"])
movie_count = year_gb.count()["original_title"]
movie_count_chart= movie_count.plot(kind= "bar", figsize=(20,5))
plt.title("Movie Count per Year")
movie_count_chart.set_ylabel("Count")
plt.show()

# %%
good_movies_per_year = year_gb.sum()["Good_or_Bad_Movie"]
good_movies_per_year
# Out:
# year
# 1912     0
# 1913     0
# 1914     0
# 1915     0
# 1916     1
#         ..
# 2016    27
# 2017    27
# 2018    36
# 2019    24
# 2020     2
# Name: Good_or_Bad_Movie, Length: 109, dtype: int64

# %%
IMDB =movie_df["avg_vote"]
duration = movie_df["duration"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(IMDB, duration)
regress_values = IMDB * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(IMDB, duration)

plt.plot(IMDB,regress_values,"r-")
plt.annotate(line_eq,(3,250),fontsize=15,color="red")
plt.xlabel('IMDB rating')
plt.ylabel('movie duration')
plt.show()

# %%
IMDB =movie_df["avg_vote"]
budget = movie_df["budget"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(IMDB, budget)
regress_values = IMDB * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(IMDB, budget)

plt.plot(IMDB,regress_values,"r-")
plt.annotate(line_eq,(2,300000000),fontsize=15,color="red")
plt.xlabel('IMDB rating')
plt.ylabel('budget')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(duration, budget)
regress_values = duration * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(duration, budget)

plt.plot(duration,regress_values,"r-")
plt.annotate(line_eq,(100,300000000),fontsize=15,color="red")
plt.xlabel('duration')
plt.ylabel('budget')
plt.show()

# %%
votes = movie_df["votes"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(IMDB, votes)
regress_values = IMDB * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(IMDB, votes)

#plt.plot(IMDB,regress_values,"r-")
#plt.annotate(line_eq,(20,100),fontsize=15,color="red")
plt.xlabel('IMDB rating')
plt.ylabel('votes')
plt.show()

# %%
lan = movie_df["number_of_languages"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(IMDB, lan)
regress_values = IMDB * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(IMDB, lan)


plt.xlabel('IMDB rating')
plt.ylabel('Number of Languages')
plt.show()

# %%
no_genres = movie_df["number_of_genres"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(IMDB, no_genres)
regress_values = IMDB * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(IMDB, no_genres)


plt.xlabel('IMDB rating')
plt.ylabel('number_of_genres')
plt.show()

# %%
budget_bins = [9999,99999,999999,9999999,99999999,999999999]
budget_range = ["<100K","100K-1M","1M-10M","10M-100M","100M-1B"]
budget_df = movie_df.loc[:,["avg_vote","budget", "original_title", "duration"]].drop_duplicates()
budget_df["budget_cut"]=pd.cut(budget_df["budget"], budget_bins, labels = budget_range)

budget_df_gb = budget_df.groupby("budget_cut")
avg_imdb_score = budget_df_gb["avg_vote"].mean()

# %%
budget_count = budget_df["budget_cut"].value_counts()

# %%
budget_count_df = pd.DataFrame({"Total Count":budget_count, "avg_score": avg_imdb_score })
budget_count_df.sort_index()
# Out:
#           Total Count  avg_score
# <100K             929   4.736168
# 100K-1M          2468   5.503201
# 1M-10M           3839   5.778302
# 10M-100M         2694   6.164514
# 100M-1B           218   6.633486

# %%
#budget_count_df["avg_imdb_score"]
#budget_count
avg_imdb_score
# Out:
# budget_cut
# <100K       4.736168
# 100K-1M     5.503201
# 1M-10M      5.778302
# 10M-100M    6.164514
# 100M-1B     6.633486
# Name: avg_vote, dtype: float64

# %%
new_imdb = avg_imdb_score
new_budget = budget_count
(slope, intercept, rvalue, pvalue, stderr) = linregress(new_imdb, new_budget)
regress_values = new_imdb * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(new_imdb, new_budget)

plt.plot(new_imdb,regress_values,"r-")
plt.annotate(line_eq,(5,4000),fontsize=15,color="red")
plt.xlabel('new_imdb rating')
plt.ylabel('movie count')
plt.show()

# %%
budget_df["budget_cut"]
# Out:
# 0        10M-100M
# 1           <100K
# 2          1M-10M
# 3        10M-100M
# 4           <100K
#            ...
# 10340       <100K
# 10341       <100K
# 10342       <100K
# 10343         NaN
# 10344       <100K
# Name: budget_cut, Length: 10345, dtype: category
# Categories (5, object): [<100K < 100K-1M < 1M-10M < 10M-100M < 100M-1B]

# %%
#####Genre######

# %%
unique_genre = len(movie_df["genre"].unique())
print("number of unique genre:", unique_genre)
# Out:
# number of unique genre: 22

# %%
genre_list = movie_df["genre"].unique()
genre_list
# Out:
# array(['Romance', 'Horror', 'Action', 'Sci-Fi', 'Comedy', 'Drama',
#        'Crime', 'Thriller', 'Biography', 'Adventure', 'Western',
#        'Animation', 'Fantasy', 'Family', 'Mystery', 'Music', 'Musical',
#        'Sport', 'Documentary', 'War', 'History', 'Film-Noir'],
#       dtype=object)

# %%
genre_gb = movie_df.groupby(["genre", "avg_vote","duration"]).size().reset_index().rename(columns={0:'count'})
genre_gb_df = genre_gb.reset_index()
genre_gb_df
# Out:
#       index    genre  avg_vote  duration  count
# 0         0   Action       1.2        80      1
# 1         1   Action       1.3        71      1
# 2         2   Action       1.4        90      1
# 3         3   Action       1.5        87      1
# 4         4   Action       1.5        90      1
# ...     ...      ...       ...       ...    ...
# 7066   7066  Western       7.3        92      1
# 7067   7067  Western       7.3        96      1
# 7068   7068  Western       7.3       104      1
# 7069   7069  Western       7.4       111      1
# 7070   7070  Western       7.8       135      1
#
# [7071 rows x 5 columns]

# %%
genre_avg_imdb_df = movie_df.groupby(["genre"])["avg_vote"].mean()
genre_avg_imdb_df.head(20) 
#avg_imdb = genre_gb2(["avg_vote"]).mean()
#avg_imdb
# Out:
# genre
# Action         5.527679
# Adventure      5.993293
# Animation      6.453138
# Biography      6.779866
# Comedy         5.778223
# Crime          6.158747
# Documentary    7.500000
# Drama          6.114233
# Family         4.969048
# Fantasy        5.211392
# Film-Noir      7.280000
# History        6.571429
# Horror         4.362098
# Music          6.600000
# Musical        6.257143
# Mystery        5.920000
# Romance        5.789091
# Sci-Fi         4.240000
# Sport          6.550000
# Thriller       4.510000
# Name: avg_vote, dtype: float64

# %%
budget_bins = [9999,99999,999999,9999999,99999999,999999999]
budget_range = ["<100K","100K-1M","1M-10M","10M-100M","100M-1B"]
budget_df2 = movie_df.loc[:,["avg_vote","budget", "original_title", "duration","genre"]].drop_duplicates()
budget_df2["budget_cut"]=pd.cut(budget_df["budget"], budget_bins, labels = budget_range)

budget_df2
# Out:
#        avg_vote    budget                             original_title  \
# 0           4.7  25000000  10 Things We Should Do Before We Break Up
# 1           3.8     60000                           Abigail Haunting
# 2           4.5   5000000               Malibu Rescue: The Next Wave
# 3           4.7  30000000                          The Tax Collector
# 4           2.2     10000                  Camp Blood 8: Revelations
# ...         ...       ...                                        ...
# 10340       6.3     25000                      The Perils of Pauline
# 10341       6.1     40000                         Judith of Bethulia
# 10342       5.2     23500           His Majesty, the Scarecrow of Oz
# 10343       6.0      5700                           Traffic in Souls
# 10344       5.2     45000                                  Cleopatra
#
#        duration    genre budget_cut
# 0            74  Romance   10M-100M
# 1            85   Horror      <100K
# 2            68   Action     1M-10M
# 3            95   Action   10M-100M
# 4            82   Horror      <100K
# ...         ...      ...        ...
# 10340       199   Action      <100K
# 10341        61    Drama      <100K
# 10342        59   Family      <100K
# 10343        88    Crime        NaN
# 10344       100    Drama      <100K
#
# [10345 rows x 6 columns]

# %%
test1 = budget_df2.groupby(["genre"])
test2 = test1["budget_cut"].value_counts()
test2
# Out:
# genre    budget_cut
# Action   10M-100M      618
#          1M-10M        600
#          100K-1M       294
#          100M-1B       125
#          <100K          93
#                       ...
# War      100K-1M         2
# Western  1M-10M         43
#          100K-1M        35
#          <100K          10
#          10M-100M        2
# Name: budget_cut, Length: 83, dtype: int64

# %%
test2.unstack(0).plot.bar(stacked=True, figsize=(15,10))
plt.ylabel('Total movie count base on budget');
plt.show()

# %%
test3 = budget_df2.groupby(["budget_cut"])
test4 = test3["genre"].value_counts()
test4
# Out:
# budget_cut  genre
# <100K       Horror       264
#             Comedy       217
#             Drama        191
#             Action        93
#             Crime         57
#                         ...
# 100M-1B     Comedy         7
#             Drama          6
#             Biography      3
#             Crime          1
#             Family         1
# Name: genre, Length: 83, dtype: int64

# %%
test4.unstack(0).plot.bar(stacked=True, figsize=(15,10))
plt.ylabel('Total movie count based on Genre');
plt.show()

# %%
######Top 5 Genre ############
genre_list = ["Action","Drama","Comedy","Horror","Crime"]
selected_genre_df = movie_df[movie_df.genre.isin(genre_list)]
selected_genre_df
# Out:
#       imdb_title_id                original_title  year  \
# 1        tt10740584              Abigail Haunting  2020
# 2        tt11032990  Malibu Rescue: The Next Wave  2020
# 3         tt8461224             The Tax Collector  2020
# 4        tt11547496     Camp Blood 8: Revelations  2020
# 6        tt11845692     Tales from Six Feet Under  2020
# ...             ...                           ...   ...
# 10339     tt0004635                 The Squaw Man  1914
# 10340     tt0004465         The Perils of Pauline  1914
# 10341     tt0004181            Judith of Bethulia  1914
# 10343     tt0003471              Traffic in Souls  1913
# 10344     tt0002101                     Cleopatra  1912
#
#                           genre2  duration language  \
# 1                         Horror        85  English
# 2      Action, Adventure, Comedy        68  English
# 3           Action, Crime, Drama        95  English
# 4                         Horror        82  English
# 6                 Comedy, Horror        45  English
# ...                          ...       ...      ...
# 10339     Action, Drama, Romance        74  English
# 10340   Action, Adventure, Drama       199  English
# 10341                      Drama        61  English
# 10343               Crime, Drama        88  English
# 10344             Drama, History       100  English
#
#                                      production_company  avg_vote  votes  \
# 1                                    Indie Film Factory       3.8    398
# 2                             Pacific Bay Entertainment       4.5    386
# 3                              Cedar Park Entertainment       4.7   4862
# 4                                Sterling Entertainment       2.2    114
# 6                                                   NaN       7.6    223
# ...                                                 ...       ...    ...
# 10339               Jesse L. Lasky Feature Play Company       5.7    879
# 10340                                    Path̩ Fr̬res       6.3    939
# 10341                                  Biograph Company       6.1   1239
# 10343  Independent Moving Pictures Co. of America (IMP)       6.0    552
# 10344                     Helen Gardner Picture Players       5.2    446
#
#          budget  Good_or_Bad_Movie  number_of_genres  number_of_languages  \
# 1         60000                  0                 1                    1
# 2       5000000                  0                 3                    1
# 3      30000000                  0                 3                    1
# 4         10000                  0                 1                    1
# 6          1500                  1                 2                    1
# ...         ...                ...               ...                  ...
# 10339     20000                  0                 3                    1
# 10340     25000                  0                 3                    1
# 10341     40000                  0                 1                    1
# 10343      5700                  0                 2                    1
# 10344     45000                  0                 2                    1
#
#         genre  Good_or_Bad_Movie_6_or_higher  Good_or_Bad_Movie_8_or_higher
# 1      Horror                              0                              0
# 2      Action                              0                              0
# 3      Action                              0                              0
# 4      Horror                              0                              0
# 6      Comedy                              1                              0
# ...       ...                            ...                            ...
# 10339  Action                              0                              0
# 10340  Action                              1                              0
# 10341   Drama                              1                              0
# 10343   Crime                              1                              0
# 10344   Drama                              0                              0
#
# [8741 rows x 16 columns]

# %%
select_test = selected_genre_df.groupby("genre")
select_test2 = select_test["year"].value_counts()
select_test2
# Out:
# genre   year
# Action  2010    69
#         2016    69
#         2013    66
#         2009    63
#         2012    60
#                 ..
# Horror  1934     1
#         1941     1
#         1956     1
#         1969     1
#         1994     1
# Name: year, Length: 475, dtype: int64

# %%
select_test2.unstack(0).plot.bar(stacked=True, figsize=(15,10))
plt.ylabel('Movie count');
plt.show()

# %%
select_test3 = selected_genre_df.groupby(["genre","year"])
select_test4 = select_test3["avg_vote"].mean()
select_test4
# Out:
# genre   year
# Action  1914    6.000000
#         1916    6.200000
#         1923    8.100000
#         1926    7.300000
#         1928    6.533333
#                   ...
# Horror  2016    4.126829
#         2017    4.437500
#         2018    3.995349
#         2019    3.880952
#         2020    2.716667
# Name: avg_vote, Length: 475, dtype: float64

# %%
select_test4.unstack(0).plot.line(stacked=False, figsize=(15,10))
plt.ylabel('Avg imdb rating');
plt.show()

# %%
unique_PC = len(movie_df["production_company"].unique())
print("number of unique production_company:", production_company)
# Out:
# number of unique production_company: 4815

# %%
select_test8 = movie_df.groupby('production_company').size().sort_values(ascending=False)
#select_test9 = select_test8["original_title"].count().sort_by(Ascending =False)
select_test8
# Out:
# production_company
# Metro-Goldwyn-Mayer (MGM)     573
# Warner Bros.                  348
# Twentieth Century Fox         316
# Paramount Pictures            297
# Columbia Pictures             287
#                              ...
# Jolie Pas                       1
# Joint Productions               1
# Johnny Tao Productions LLC      1
# John Wells Productions          1
# 'Am I Wrong?' Productions       1
# Length: 4814, dtype: int64

# %%
selected_PC = ["Archway Pictures","APB Production","Orion-Nova Productions","All You Can Dream", "Marlowe/Pugnetti Company", "StarKid Productions","Strong Heart/Demme Production", "Sing Out Louise Productions", "Cecchi Gori Pictures", "Disney Theatrical Productions (DTP)"]
selected_PC_df = movie_df[movie_df.production_company.isin(selected_PC)]
selected_PC_df
# Out:
#      imdb_title_id                          original_title  year  \
# 87       tt6735740                        Love in Kilnerry  2019
# 104     tt10218912                                 As I Am  2019
# 316      tt9509866        The Guy Who Didn't Like Musicals  2018
# 616      tt6346162  Disney's Newsies: The Broadway Musical  2017
# 745      tt6316170               George Takei's Allegiance  2016
# 2184     tt1723122                       All You Can Dream  2012
# 4571     tt0419781                              Graves End  2005
# 6217     tt0114369                                   Se7en  1995
# 6671     tt0102926                The Silence of the Lambs  1991
# 8818     tt0050083                            12 Angry Men  1957
#
#                        genre2  duration        language  \
# 87                     Comedy       100         English
# 104   Drama, Fantasy, Romance        62         English
# 316           Comedy, Musical       112         English
# 616                   Musical       149         English
# 745                   Musical       130         English
# 2184    Comedy, Drama, Family        79         English
# 4571        Thriller, Mystery        90         English
# 6217    Crime, Drama, Mystery       127         English
# 6671   Crime, Drama, Thriller       118  English, Latin
# 8818             Crime, Drama        96         English
#
#                        production_company  avg_vote    votes    budget  \
# 87                       Archway Pictures       9.3     1239   3000000
# 104                        APB Production       9.3     1173     10000
# 316                   StarKid Productions       8.7      330    130000
# 616   Disney Theatrical Productions (DTP)       8.5     1953   2000000
# 745           Sing Out Louise Productions       8.6      189   1000000
# 2184                    All You Can Dream       8.8      879   2000000
# 4571             Marlowe/Pugnetti Company       8.8     6494   1930000
# 6217                 Cecchi Gori Pictures       8.6  1402015  33000000
# 6671        Strong Heart/Demme Production       8.6  1234134  19000000
# 8818               Orion-Nova Productions       8.9   668473    350000
#
#       Good_or_Bad_Movie  number_of_genres  number_of_languages     genre  \
# 87                    1                 1                    1    Comedy
# 104                   1                 3                    1     Drama
# 316                   1                 2                    1    Comedy
# 616                   1                 1                    1   Musical
# 745                   1                 1                    1   Musical
# 2184                  1                 3                    1    Comedy
# 4571                  1                 2                    1  Thriller
# 6217                  1                 3                    1     Crime
# 6671                  1                 3                    2     Crime
# 8818                  1                 2                    1     Crime
#
#       Good_or_Bad_Movie_6_or_higher  Good_or_Bad_Movie_8_or_higher
# 87                                1                              1
# 104                               1                              1
# 316                               1                              1
# 616                               1                              1
# 745                               1                              1
# 2184                              1                              1
# 4571                              1                              1
# 6217                              1                              1
# 6671                              1                              1
# 8818                              1                              1

# %%
print(selected_PC)
# Out:
# ['Archway Pictures', 'APB Production', 'Orion-Nova Productions', 'All You Can Dream', 'Marlowe/Pugnetti Company', 'StarKid Productions', 'Strong Heart/Demme Production', 'Sing Out Louise Productions', 'Cecchi Gori Pictures', 'Disney Theatrical Productions (DTP)']
